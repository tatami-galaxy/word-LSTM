# %%
import numpy as np
import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.nn.parameter import Parameter
import string
import random
from random import randint
from fastText import load_model
import torch.backends.cudnn as cudnn

# %%
# Read data into string, split into words and finally separate into train and valid sets
valid_size = 1000

with open('text8') as file:
    data = file.read()
words = data.split()
valid_words = words[:valid_size]
train_words = words[valid_size:]
train_size = len(train_words)

print(valid_size, valid_words[:10])
print(train_size, train_words[:10])
# Out:
# 1000 ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# 17004207 ['american', 'individualist', 'anarchism', 'benjamin', 'tucker', 'in', 'one', 'eight', 'two', 'five']

# %%
# Use fasttext excecutable in fastText-0.1.0 folder to build bin (and vec) file containing word embeddings
# Load bin file into fasttext model
ft_model = load_model('text8_ft.bin')

# %%
# dictionary -> word : embedding
# index_dictionary -> index : word
# reverse_index_dictionary -> word : index
dictionary = {'UNK' : ft_model.get_word_vector('UNK')}
index_dictionary = {0 : 'UNK'}
all_words = ft_model.get_words()
for word in all_words:
    dictionary[word] = ft_model.get_word_vector(word)
    index_dictionary[len(index_dictionary)] = word
reverse_index_dictionary = dict(zip(index_dictionary.values(), index_dictionary.keys()))

print('Vocabulary size : %d' % len(dictionary))
# Out:
# Vocabulary size : 71291

# %%
vocab_size = len(dictionary)
num_dimensions = 300
batch_size = 64
num_unrollings = 10

# Generate batches parallely across the text at equal intervals
# Each batch contains one word from each of the positions
# Positions are updated after generating every batch
# The next batch would therefore contain the next words from all the chosen positions
# num_unrollings number of batches are processed at once
# Each word is represented as an embedding
class BatchGenerator(object):
    def __init__(self, corpus, batch_size, num_unrollings):
        self._corpus = corpus
        self._corpus_size = len(corpus)
        self._batch_size = batch_size
        self._num_unrollings = num_unrollings
        segment = self._corpus_size // batch_size
        self._cursor = [offset*segment for offset in range(batch_size)]
        self._last_batch, self._last_indices = self._next_batch()
        
    def _next_batch(self):
        #print('')
        batch = np.zeros(shape=(self._batch_size, num_dimensions), dtype=np.float)
        word_indices = np.zeros(shape=(self._batch_size,), dtype=np.int64)
        for b in range(self._batch_size):
            word = self._corpus[self._cursor[b]]
            if word not in dictionary:
                batch[b] = dictionary['UNK']
                word_indices[b] = reverse_index_dictionary['UNK']
            else:
                batch[b] = dictionary[word]
                word_indices[b] = reverse_index_dictionary[word]
            #print(word, end='')
            #print(' ', end='')
            self._cursor[b] = (self._cursor[b] + 1) % self._corpus_size
        #print('')
        return batch, word_indices
    
    def _next(self):
        batches = [self._last_batch]
        indices = [self._last_indices]
        for step in range(self._num_unrollings):
            batch, word_indices = self._next_batch()
            batches.append(batch)
            indices.append(word_indices)
        self._last_batch = batches[-1]
        self._last_indices = indices[-1]
        return batches, indices
    
train_batches = BatchGenerator(train_words, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_words, 1, 1)

# %%
dtype = torch.FloatTensor
hidden_size = 1024

class LSTM(nn.Module):
    
    def __init__(self, num_dimensions, hidden_size):
        super(LSTM, self).__init__()
        # LSTM architecture
        
        # Layer 1
        self.inputW1 = nn.Linear(num_dimensions, hidden_size)
        self.inputU1 = nn.Linear(hidden_size, hidden_size)
        self.forgetW1 = nn.Linear(num_dimensions, hidden_size)
        self.forgetU1 = nn.Linear(hidden_size, hidden_size)
        self.outputW1 = nn.Linear(num_dimensions, hidden_size)
        self.outputU1 = nn.Linear(hidden_size, hidden_size)
        self.cellW1 = nn.Linear(num_dimensions, hidden_size)
        self.cellU1 = nn.Linear(hidden_size, hidden_size)
        
        # Layer 2
        self.inputW2 = nn.Linear(hidden_size, hidden_size)
        self.inputU2 = nn.Linear(hidden_size, hidden_size)
        self.forgetW2 = nn.Linear(hidden_size, hidden_size)
        self.forgetU2 = nn.Linear(hidden_size, hidden_size)  
        self.outputW2 = nn.Linear(hidden_size, hidden_size)
        self.outputU2 = nn.Linear(hidden_size, hidden_size)     
        self.cellW2 = nn.Linear(hidden_size, hidden_size)
        self.cellU2 = nn.Linear(hidden_size, hidden_size)
        
        # Softmax weight
        self.softW = nn.Linear(hidden_size, vocab_size)
        # Dropout
        self.dropout = nn.Dropout(0)
        
    def forward(self, embeddings, cell_prev, hidden_prev, batch_size):
        sig = nn.Sigmoid()
        tnh = nn.Tanh()
        
        # Extract cell and hidden data for each layer
        cell_prev = Variable(cell_prev)
        hidden_prev = Variable(hidden_prev)
        cell_prev1 = cell_prev[:batch_size, :]
        hidden_prev1 = hidden_prev[:batch_size, :]
        cell_prev2 = cell_prev[batch_size:, :]
        hidden_prev2 = hidden_prev[batch_size:, :]
        
        # Layer 1 computation
        input_gate = sig(self.inputW1(embeddings) + self.inputU1(hidden_prev1))
        forget_gate = sig(self.forgetW1(embeddings) + self.forgetU1(hidden_prev1))
        output_gate = sig(self.outputW1(embeddings) + self.outputU1(hidden_prev1))
        update = tnh(self.cellW1(embeddings) + self.cellU1(hidden_prev1))
        cell1 = (forget_gate * cell_prev1) + (input_gate * update)
        hidden1 = output_gate * tnh(cell1)
        
        # Layer 2 computation
        input_gate = sig(self.inputW2(hidden1) + self.inputU2(hidden_prev2))
        forget_gate = sig(self.forgetW2(hidden1) + self.forgetU2(hidden_prev2))
        output_gate = sig(self.outputW2(hidden1) + self.outputU2(hidden_prev2))
        update = tnh(self.cellW2(hidden1) + self.cellU2(hidden_prev2))
        cell2 = (forget_gate * cell_prev2) + (input_gate * update)
        hidden2 = output_gate * tnh(cell2)
        
        # Output
        logits = self.softW(hidden2)
        logits = self.dropout(logits)
        cell = torch.cat((cell1, cell2), dim=0)
        hidden = torch.cat((hidden2, hidden2), dim=0)
        
        return cell.data, hidden.data, logits

lstm = LSTM(num_dimensions, hidden_size)
lstm.cuda()
# Out:
# LSTM(
#   (inputW1): Linear(in_features=300, out_features=1024)
#   (inputU1): Linear(in_features=1024, out_features=1024)
#   (forgetW1): Linear(in_features=300, out_features=1024)
#   (forgetU1): Linear(in_features=1024, out_features=1024)
#   (outputW1): Linear(in_features=300, out_features=1024)
#   (outputU1): Linear(in_features=1024, out_features=1024)
#   (cellW1): Linear(in_features=300, out_features=1024)
#   (cellU1): Linear(in_features=1024, out_features=1024)
#   (inputW2): Linear(in_features=1024, out_features=1024)
#   (inputU2): Linear(in_features=1024, out_features=1024)
#   (forgetW2): Linear(in_features=1024, out_features=1024)
#   (forgetU2): Linear(in_features=1024, out_features=1024)
#   (outputW2): Linear(in_features=1024, out_features=1024)
#   (outputU2): Linear(in_features=1024, out_features=1024)
#   (cellW2): Linear(in_features=1024, out_features=1024)
#   (cellU2): Linear(in_features=1024, out_features=1024)
#   (softW): Linear(in_features=1024, out_features=71291)
#   (dropout): Dropout(p=0)
# )

# %%
class StateManager(object):
    def __init__(self):
        self.hidden_state = torch.zeros(2*batch_size, hidden_size).type(dtype)
        self.cell_state = torch.zeros(2*batch_size, hidden_size).type(dtype)
        
    def save_state(self, cell_state, hidden_state):
        self.cell_state = cell_state
        self.hidden_state = hidden_state
        
    def load_state(self):
        return self.cell_state, self.hidden_state
    
    def reset_state(self):
        self.hidden_state = torch.zeros(2*batch_size, hidden_size).type(dtype)
        self.cell_state = torch.zeros(2*batch_size, hidden_size).type(dtype)
        
sm = StateManager()

# %%
learning_rate = 0.1
optimizer = torch.optim.SGD(lstm.parameters(), lr=learning_rate)

def train():
    cell, hidden = sm.load_state()
    batches, indices = train_batches._next()
    optimizer.zero_grad()
    lstm.zero_grad()
    loss_function = nn.CrossEntropyLoss()
    loss = 0
    for u in range(num_unrollings):
        embeddings = Variable(torch.from_numpy(batches[u]).type(dtype), requires_grad=False)
        cell, hidden, logits = lstm(embeddings.cuda(), cell.cuda(), hidden.cuda(), batch_size)
        labels = Variable(torch.from_numpy(indices[u+1]))
        loss += loss_function(logits.cuda(), labels.cuda())
    loss.backward()
    torch.nn.utils.clip_grad_norm(lstm.parameters(), 5) #1.25
    optimizer.step()
    sm.save_state(cell, hidden)
    return loss / num_unrollings

# %%
# Generate a random character and feed to model
# Take predicted character and feed it back again to generate subsequent characters

def sample_distribution(distribution):
# Sample one element from a distribution assumed to be an array of normalized probabilities
    r = random.uniform(0, 1)
    s = 0
    for i in range(len(distribution)):
        s += distribution[i]
        if s >= r:
            return i
    return len(distribution) - 1

def sample():
    word_id = randint(0, vocab_size-1)
    print(index_dictionary[word_id], end='')
    print(' ', end='')
    cell = torch.zeros(2*1, hidden_size).type(dtype)
    hidden = torch.zeros(2*1, hidden_size).type(dtype) 
    soft = nn.Softmax(dim=1)
    for i in range(12):
        numpy_vector = dictionary[index_dictionary[word_id]].reshape(1, num_dimensions)
        word_vector = torch.from_numpy(numpy_vector).type(dtype)
        word_vector = Variable(word_vector, requires_grad=False)
        cell, hidden, logits = lstm(word_vector.cuda(), cell.cuda(), hidden.cuda(), 1)
        output = soft(logits)
        word_id = sample_distribution(output.data[0])
        print(index_dictionary[word_id], end='')
        print(' ', end='')
    print(' ')

# %%
def valid_perplexity():
    loss_function = nn.CrossEntropyLoss()
    loss = 0
    cell = torch.zeros(2*1, hidden_size).type(dtype)
    hidden = torch.zeros(2*1, hidden_size).type(dtype)
    for i in range(valid_size):
        batches, indices = valid_batches._next()
        word_vectors = Variable(torch.from_numpy(batches[0]).type(dtype), requires_grad=False)
        cell, hidden, logits = lstm(word_vectors.cuda(), cell.cuda(), hidden.cuda(), 1)
        labels = Variable(torch.from_numpy(indices[1]))
        loss += loss_function(logits.cuda(), labels.cuda())
    return torch.exp(loss / valid_size)

# %%
num_iters = 300001 

cudnn.benchmark = True
cudnn.fasttest = True

for i in range(num_iters):
    lstm.train()
    l = train()
    if i%1000 == 0: 
        print('Average loss at step %d: %.3f ' % (i,l))
        print('Minibatch perplexity: %.3f' % torch.exp(l))
        print('Validation perplexity: %.3f' % valid_perplexity())
        lstm.eval()
        sample()
        print('')
# Out:
# Average loss at step 0: 11.177
# Minibatch perplexity: 71481.344
# Validation perplexity: 70671.266
# coloane chairperson include artcyclopedia osteoporosis tsetse gait begun guru recent dracula pluck tmc
#
# Average loss at step 1000: 7.463
# Minibatch perplexity: 1742.593
# Validation perplexity: 2060.778
# consultum symbols idiomatic relaunch perpendicular kroll significance dorothy restrictions for proposed fast intrinsic
#
# Average loss at step 2000: 7.020
# Minibatch perplexity: 1118.893
# Validation perplexity: 1484.531
# entrees proves affan encephalopathy voted olympian primordial in frequenting target wales question space
#
# Average loss at step 3000: 6.964
# Minibatch perplexity: 1057.770
# Validation perplexity: 1520.071
# politican suzerain combe alignments ank navy plagiarized jigoro leader pashtun authorized the construct
#
# Average loss at step 4000: 6.856
# Minibatch perplexity: 949.657
# Validation perplexity: 1000.979
# abate piran svante errol distinction nanyang overpasses tabular hussain fargo de intentional stacking
#
# Average loss at step 5000: 6.545
# Minibatch perplexity: 695.670
# Validation perplexity: 805.004
# lazzaro saviola nephew great marked than refers that iers and they have arrangement
#
# Average loss at step 6000: 6.174
# Minibatch perplexity: 480.013
# Validation perplexity: 819.440
# macneille spreadsheet dorn bibliography in ghorids five grace was published nine nine seven
#
# Average loss at step 7000: 6.237
# Minibatch perplexity: 511.452
# Validation perplexity: 656.562
# convective maximizing cimon hub legal kong disagreed between the black archie or caught
#
# Average loss at step 8000: 6.013
# Minibatch perplexity: 408.590
# Validation perplexity: 637.397
# mujahideen academy agnostids expense powers greatly at legal areas ethnic in virgin which
#
# Average loss at step 9000: 6.160
# Minibatch perplexity: 473.612
# Validation perplexity: 565.139
# leper musashi morag aerobics pazzi active weapons anti claims s postulated situation continue
#
# Average loss at step 10000: 6.163
# Minibatch perplexity: 475.020
# Validation perplexity: 539.535
# pinyin rhodesian thursdays clarence jihad jedi may breakfast and other the definitions of
#
# Average loss at step 11000: 5.966
# Minibatch perplexity: 389.860
# Validation perplexity: 553.734
# sections disagree liquor handled end on two million days on how can contain
#
# Average loss at step 12000: 5.781
# Minibatch perplexity: 323.961
# Validation perplexity: 470.182
# antiseptics conomique germans foundation musik rg maple columbus includes the cape islands indies
#
# Average loss at step 13000: 5.915
# Minibatch perplexity: 370.440
# Validation perplexity: 456.427
# jeffreys snowdonia upton teleco had cheeses appeared with studying of rabbis civilization and
#
# Average loss at step 14000: 5.696
# Minibatch perplexity: 297.679
# Validation perplexity: 461.470
# tufts getting origination shaders separate winning weapon for common games some of scarecrow
#
# Average loss at step 15000: 5.822
# Minibatch perplexity: 337.711
# Validation perplexity: 476.859
# dublin panoramas corporum wabash emblem governing kandy opens a running of the international
#
# Average loss at step 16000: 5.661
# Minibatch perplexity: 287.506
# Validation perplexity: 464.019
# ashur polygamy fracturing thirty ainu gained his sixty the anti newspaper taken the
#
# Average loss at step 17000: 5.475
# Minibatch perplexity: 238.566
# Validation perplexity: 426.828
# additionally formartine sensibility reliable parties in one nine four eight and three one
#
# Average loss at step 18000: 5.755
# Minibatch perplexity: 315.717
# Validation perplexity: 431.889
# aleman unsustainable freedb implacable refreshing dedham s upstate archives from gates a single
#
# Average loss at step 19000: 5.831
# Minibatch perplexity: 340.868
# Validation perplexity: 414.400
# referenced spec bengali therefore all lcds in tiny radio and are pronounced a
#
# Average loss at step 20000: 5.495
# Minibatch perplexity: 243.469
# Validation perplexity: 434.579
# wolfowitz virtuosic bernini underpants and other physical concepts over his plutonium along booths
#
# Average loss at step 21000: 5.830
# Minibatch perplexity: 340.416
# Validation perplexity: 406.694
# unhappily unfamiliarity commonplace they are usually able to take the zcoa the opening
#
# Average loss at step 22000: 5.446
# Minibatch perplexity: 231.783
# Validation perplexity: 385.851
# tremendous millenarianism contention denounced when war and corresponds to time that independence had
#
# Average loss at step 23000: 5.274
# Minibatch perplexity: 195.179
# Validation perplexity: 394.673
# moraine medica godoy rejects first in teaching it was said to have secretly
#
# Average loss at step 24000: 5.720
# Minibatch perplexity: 305.000
# Validation perplexity: 378.904
# peppermint domini philip ability known as the writings in diameter or muhsin called
#
# Average loss at step 25000: 5.650
# Minibatch perplexity: 284.324
# Validation perplexity: 380.281
# jupiters phrygians ula brubeck isidore lad hardback phonation for reciprocal and write on
#
# Average loss at step 26000: 5.824
# Minibatch perplexity: 338.308
# Validation perplexity: 350.166
# adom cytology textiles vx norman oxide lethargy esters nutritional green or coke ultraviolet
#
# Average loss at step 27000: 5.612
# Minibatch perplexity: 273.652
# Validation perplexity: 315.335
# stanford astrologer allocating february three one eight five five one and in democratic
#
# Average loss at step 28000: 5.366
# Minibatch perplexity: 213.968
# Validation perplexity: 368.373
# rehearsal tragic day has also been observed in his dramatic change latte song
#
# Average loss at step 29000: 5.389
# Minibatch perplexity: 218.958
# Validation perplexity: 355.701
# compaction unmaking rapid grounds encourages to making out confusion observation because that the
#
# Average loss at step 30000: 5.473
# Minibatch perplexity: 238.229
# Validation perplexity: 331.938
# incalculable penniless involves absolute military alternatives uses intellectual talent painting of classical vienna
#
# Average loss at step 31000: 5.565
# Minibatch perplexity: 261.118
# Validation perplexity: 317.869
# benson zainab and minsk drugs western victorian and new york city overlooking west
#
# Average loss at step 32000: 5.264
# Minibatch perplexity: 193.268
# Validation perplexity: 342.892
# dithmarschen artbook thirsty rate of this size the real amount range from reference
#
# Average loss at step 33000: 5.237
# Minibatch perplexity: 188.172
# Validation perplexity: 318.381
# rolls compared to him sigismund kampf one eight eight one although the dromedary
#
# Average loss at step 34000: 5.771
# Minibatch perplexity: 320.793
# Validation perplexity: 344.487
# bergman catharine cruciger gate pasternak devised the crusade of bernardo heero usually indigenous
#
# Average loss at step 35000: 5.459
# Minibatch perplexity: 234.834
# Validation perplexity: 318.770
# personalities province glitch belt wars adopted by the uralic language verb or welsh
#
# Average loss at step 36000: 5.235
# Minibatch perplexity: 187.761
# Validation perplexity: 329.323
# audits gutar waged knesset committee in one nine six six microsoft s standards
#
# Average loss at step 37000: 5.890
# Minibatch perplexity: 361.400
# Validation perplexity: 302.006
# yu fanzine nemesis cymbal generated kinematics texture and elements electric electric hadad la
#
# Average loss at step 38000: 5.247
# Minibatch perplexity: 189.922
# Validation perplexity: 336.171
# edification birthright facings capped when rijeka bluebird has been debated by the germanic
#
# Average loss at step 39000: 5.522
# Minibatch perplexity: 250.017
# Validation perplexity: 271.769
# petrels rudi technocrats furioso authorising UNK keith cooper was born in sarajevo vale
#
# Average loss at step 40000: 5.543
# Minibatch perplexity: 255.321
# Validation perplexity: 295.072
# advantageously necessarily deprogramming based the outside but on which at it one in
#
# Average loss at step 41000: 4.876
# Minibatch perplexity: 131.109
# Validation perplexity: 313.341
# rowland bloc agricultural in addition to the mixed japanese products of the moroccan
#
# Average loss at step 42000: 5.533
# Minibatch perplexity: 252.957
# Validation perplexity: 283.646
# hurt stoned somewhat closer to the gentlemen three and more a star that
#
# Average loss at step 43000: 5.199
# Minibatch perplexity: 181.096
# Validation perplexity: 280.340
# covers logged over weeks the same year in minnesota in one nine eight
#
# Average loss at step 44000: 5.339
# Minibatch perplexity: 208.406
# Validation perplexity: 298.770
# docherty winners with unprotected trust rights such as captain of a series of
#
# Average loss at step 45000: 5.778
# Minibatch perplexity: 323.087
# Validation perplexity: 281.803
# lymec expansionist reaction british fantasy basic diagram standards such as intoxicated substances or
#
# Average loss at step 46000: 5.295
# Minibatch perplexity: 199.413
# Validation perplexity: 286.552
# infer heathers entice UNK the latest star probe to print the screen is
#
# Average loss at step 47000: 5.057
# Minibatch perplexity: 157.063
# Validation perplexity: 299.067
# kirov deconstructionists classical norma ideals at glasnevin memorial university in philadelphia pennsylvania a
#
# Average loss at step 48000: 5.371
# Minibatch perplexity: 215.185
# Validation perplexity: 300.758
# villard kodagu vorticity master composed of six volumes of expressions mathematical formulas of
#
# Average loss at step 49000: 5.399
# Minibatch perplexity: 221.262
# Validation perplexity: 298.516
# standard employees combining the same model model e g xenocrates v pentium four
#
# Average loss at step 50000: 5.496
# Minibatch perplexity: 243.810
# Validation perplexity: 296.181
# proposer the embassies should not be sweeping in the world the dominion of
#
# Average loss at step 51000: 5.064
# Minibatch perplexity: 158.220
# Validation perplexity: 286.406
# slumping cooked livecd involving less of revamping magazine brands external links human g
#
# Average loss at step 52000: 4.873
# Minibatch perplexity: 130.771
# Validation perplexity: 265.306
# ceasing jscript demonstrating a tool of developers began to circle out in one
#
# Average loss at step 53000: 5.331
# Minibatch perplexity: 206.700
# Validation perplexity: 261.410
# kur rowspan mandaic maximizes this might be used as better but lamorna sought
#
# Average loss at step 54000: 5.028
# Minibatch perplexity: 152.612
# Validation perplexity: 256.782
# gust controllable planets have previously thought it successfully utilized the notion of making
#
# Average loss at step 55000: 5.172
# Minibatch perplexity: 176.336
# Validation perplexity: 261.127
# coalescing gsm y is more redcedar flourishing the chrysler making company typically nine
#
# Average loss at step 56000: 5.131
# Minibatch perplexity: 169.250
# Validation perplexity: 258.799
# playford provided intelsat anniversaries its final caves to within the history and television
#
# Average loss at step 57000: 5.241
# Minibatch perplexity: 188.925
# Validation perplexity: 250.947
# ceres spicy sales similar to italian and italian with eight zero zero three
#
# Average loss at step 58000: 5.394
# Minibatch perplexity: 220.058
# Validation perplexity: 263.944
# arbitron channel waff opens with fire the naylor asks to ascend the cam
#
# Average loss at step 59000: 5.094
# Minibatch perplexity: 163.054
# Validation perplexity: 262.951
# payton osmosis lifestyle technological health youth veterans american martial arts chinese martial arts
#
# Average loss at step 60000: 5.264
# Minibatch perplexity: 193.175
# Validation perplexity: 261.329
# catalysis largely unlike and bound to form the final respecting to release from
#
# Average loss at step 61000: 5.043
# Minibatch perplexity: 154.874
# Validation perplexity: 267.225
# macgregor casiquiare mozambique the brotherhood of the english song paul reeves the moniker
#
# Average loss at step 62000: 5.188
# Minibatch perplexity: 179.114
# Validation perplexity: 276.888
# royale buy fair of the united states should generally believe a dignified being
#
# Average loss at step 63000: 5.096
# Minibatch perplexity: 163.437
# Validation perplexity: 252.806
# lachaise intuition computable programming with mng developed for standardization as a new source
#
# Average loss at step 64000: 5.463
# Minibatch perplexity: 235.861
# Validation perplexity: 263.831
# simplification geronimo zombie reminded the tangerine to avenge the sulfide verisign of the
#
# Average loss at step 65000: 5.390
# Minibatch perplexity: 219.165
# Validation perplexity: 245.907
# kalinga ecclestone that immensely encouraging merry city is the central intelligence agency and
#
# Average loss at step 66000: 4.985
# Minibatch perplexity: 146.268
# Validation perplexity: 235.762
# luddite requiring poor with the money performance and quiet or rather stocks that
#
# Average loss at step 67000: 5.214
# Minibatch perplexity: 183.860
# Validation perplexity: 263.609
# trappers iran kamchatsky ducats or gilbert see a jailer a short metrics of
#
# Average loss at step 68000: 5.343
# Minibatch perplexity: 209.241
# Validation perplexity: 259.770
# sverre bradshaw giglio jean ward piet french writer in march one nine seven
#
# Average loss at step 69000: 4.819
# Minibatch perplexity: 123.888
# Validation perplexity: 240.763
# incapacitation depressant concentrating numerous rapid killings danneskjold turned down with people with the
#
# Average loss at step 70000: 5.434
# Minibatch perplexity: 229.071
# Validation perplexity: 240.230
# minefields off many alike including the germans during their fleets in which the
#
# Average loss at step 71000: 5.181
# Minibatch perplexity: 177.934
# Validation perplexity: 247.553
# conservation traditionalism auratus of phodopus UNK life of birth parents and scalp skills
#
# Average loss at step 72000: 5.155
# Minibatch perplexity: 173.375
# Validation perplexity: 243.747
# tata suites b one two zero one nine seven nine a complex z
#
# Average loss at step 73000: 5.180
# Minibatch perplexity: 177.664
# Validation perplexity: 248.328
# gemologists before rem summerson arrives to the city in one nine eight six
#
# Average loss at step 74000: 5.148
# Minibatch perplexity: 172.033
# Validation perplexity: 279.385
# thais marmalade is really described to describe a cranberry family or lesbian phylum
#
# Average loss at step 75000: 5.331
# Minibatch perplexity: 206.712
# Validation perplexity: 243.122
# dimming myself put the very unlikely moment for discovering the whole naive related
#
# Average loss at step 76000: 5.005
# Minibatch perplexity: 149.184
# Validation perplexity: 249.245
# jindo mcduck loris native retrofitting took soul during super or star times began
#
# Average loss at step 77000: 4.980
# Minibatch perplexity: 145.416
# Validation perplexity: 252.859
# discriminating crossbar dominated by the al qaeda group of the central elite and
#
# Average loss at step 78000: 5.113
# Minibatch perplexity: 166.149
# Validation perplexity: 237.654
# reusability fah pedro keeping his faithful statements her second emperor to build a
#
# Average loss at step 79000: 4.959
# Minibatch perplexity: 142.449
# Validation perplexity: 230.751
# ssris thai elas macsyma vi backus making indian mdi such as a mere
#
# Average loss at step 80000: 5.089
# Minibatch perplexity: 162.193
# Validation perplexity: 220.231
# institutions specialize and ideas and libraries for architects world biology history since the
#
# Average loss at step 81000: 4.901
# Minibatch perplexity: 134.378
# Validation perplexity: 236.214
# danmark enforceable provisions concerning all parties and other symbols the collegiate awards for
#
# Average loss at step 82000: 4.866
# Minibatch perplexity: 129.847
# Validation perplexity: 220.363
# longest ballard zimbabwean field texas divers get away ohio ivb off and uncomfortable
#
# Average loss at step 83000: 5.288
# Minibatch perplexity: 197.997
# Validation perplexity: 225.416
# novelty removed to any disguised too like the excessive depression related to the
#
# Average loss at step 84000: 4.928
# Minibatch perplexity: 138.102
# Validation perplexity: 219.894
# glimpse gwangju macedonia and nagasaki however they were not disposed in remnants as
#
# Average loss at step 85000: 4.943
# Minibatch perplexity: 140.183
# Validation perplexity: 237.908
# evidentiary methodology wrote almost exclusively in encyclopaedia because there is major contributions to
#
# Average loss at step 86000: 4.914
# Minibatch perplexity: 136.147
# Validation perplexity: 228.841
# enroll they put to certain more colleges in the us found a glass
#
# Average loss at step 87000: 5.163
# Minibatch perplexity: 174.697
# Validation perplexity: 242.770
# od gott sad ul ssang marshalsea d rd aberdare three four no three
# Average loss at step 88000: 4.927
# Minibatch perplexity: 137.913
# Validation perplexity: 229.436
# velupillai wha amputated after world war i is to say i do fall
#
# Average loss at step 89000: 4.710
# Minibatch perplexity: 111.015
# Validation perplexity: 230.306
# spur rainfall the study of spring europa is the character one nine nine
#
# Average loss at step 90000: 4.930
# Minibatch perplexity: 138.420
# Validation perplexity: 217.610
# reuniting zuider universes produced while producing safe seed before they had been added
#
# Average loss at step 91000: 4.742
# Minibatch perplexity: 114.687
# Validation perplexity: 247.108
# examination gulls swinburne lincoln has listed below the idea UNK that designs of
#
# Average loss at step 92000: 5.161
# Minibatch perplexity: 174.419
# Validation perplexity: 226.900
# albus annihilate yw b is still it the first modern guide to work
#
# Average loss at step 93000: 5.079
# Minibatch perplexity: 160.684
# Validation perplexity: 210.935
# hso saskatchewan fptp delivers the UNK to the canadian carrier tropical but the
#
# Average loss at step 94000: 4.867
# Minibatch perplexity: 129.874
# Validation perplexity: 228.426
# emitters contradicted to make animals more details in determining the subject estimates available
#
# Average loss at step 95000: 5.205
# Minibatch perplexity: 182.171
# Validation perplexity: 225.680
# pfalz albicans provincial premiers of alphonse UNK UNK kahanamoku for general of the
#
# Average loss at step 96000: 4.838
# Minibatch perplexity: 126.243
# Validation perplexity: 233.933
# plame garment problems remain within eight kilometre of lands the vistula government is
#
# Average loss at step 97000: 4.662
# Minibatch perplexity: 105.880
# Validation perplexity: 228.624
# bugs promoted the developers were split into an attempt to avoid the frame
#
# Average loss at step 98000: 5.272
# Minibatch perplexity: 194.741
# Validation perplexity: 222.916
# tonic hall university of canada brothers goats welsh welsh immigrant british scottish deaths
#
# Average loss at step 99000: 4.926
# Minibatch perplexity: 137.826
# Validation perplexity: 223.283
# handcuffs harar manure the river courthouse ruled one nine six two the rock
#
# Average loss at step 100000: 4.600
# Minibatch perplexity: 99.457
# Validation perplexity: 231.954
# choices in hong kong s clip session dave barry former promoting tv were
#
# Average loss at step 101000: 5.005
# Minibatch perplexity: 149.117
# Validation perplexity: 241.623
# stalling thugs removing a heated burst causing water back and too impingement too
#
# Average loss at step 102000: 5.191
# Minibatch perplexity: 179.680
# Validation perplexity: 228.235
# tyranny are identity radioiodine frans methyl rojcewicz s lewis hilton up in one
#
# Average loss at step 103000: 4.962
# Minibatch perplexity: 142.830
# Validation perplexity: 220.279
# rechargeable bolus dryden a mule must give the full sample amount of yours
#
# Average loss at step 104000: 4.721
# Minibatch perplexity: 112.278
# Validation perplexity: 224.328
# bodybuilding excited scar stories can discuss them about the crosby to be one
#
# Average loss at step 105000: 5.012
# Minibatch perplexity: 150.265
# Validation perplexity: 215.384
# tressure watery centrale kifl may form a tree record for the terek eagle
#
# Average loss at step 106000: 5.217
# Minibatch perplexity: 184.321
# Validation perplexity: 231.678
# religous journeys comprised each of the many animals but they are naturally hidden
#
# Average loss at step 107000: 5.023
# Minibatch perplexity: 151.923
# Validation perplexity: 206.014
# inelastic pipeline become merely dividing rocks and directions without supported by looting difficult
#
# Average loss at step 108000: 4.668
# Minibatch perplexity: 106.478
# Validation perplexity: 210.256
# epimetheus syndicate news find answers of cordwainer are based for an UNK corinne
#
# Average loss at step 109000: 4.880
# Minibatch perplexity: 131.567
# Validation perplexity: 212.275
# nar gooey notes that marked the end of the main hindu jewish world
#
# Average loss at step 110000: 5.022
# Minibatch perplexity: 151.705
# Validation perplexity: 198.616
# juridical papers sent on the flatten goes in new york where he was
#
# Average loss at step 111000: 4.722
# Minibatch perplexity: 112.442
# Validation perplexity: 208.557
# glossing corporative operations sources referred to as mikoto boutros UNK UNK since the
#
# Average loss at step 112000: 5.014
# Minibatch perplexity: 150.563
# Validation perplexity: 221.656
# ingmar amulet and ghost levels in the vicinity of UNK and mysticism begins
#
# Average loss at step 113000: 4.894
# Minibatch perplexity: 133.467
# Validation perplexity: 200.656
# schubert feller pickford in the plantation of sydney england from several early one
#
# Average loss at step 114000: 4.727
# Minibatch perplexity: 112.993
# Validation perplexity: 199.688
# rede china s congo inviting to make up the muslim language another programme
#
# Average loss at step 115000: 4.862
# Minibatch perplexity: 129.342
# Validation perplexity: 217.133
# buckle chameleon legend allmusic UNK catcher UNK character of dick and agnes every
#
# Average loss at step 116000: 5.057
# Minibatch perplexity: 157.173
# Validation perplexity: 214.045
# bombs advancing beyond a berth the relationship of enabling is a boom of
#
# Average loss at step 117000: 4.969
# Minibatch perplexity: 143.931
# Validation perplexity: 214.370
# markschies mythos randall giordano ccny policies questions for more scientific inquiry about his
#
# Average loss at step 118000: 5.005
# Minibatch perplexity: 149.145
# Validation perplexity: 219.169
# flags bureaucrats terminator donald paganini s first cartoon of games mastroianni coexists in
#
# Average loss at step 119000: 4.853
# Minibatch perplexity: 128.184
# Validation perplexity: 186.532
# fjords usbc huysmans rex UNK UNK battleship w thing game is a method
#
# Average loss at step 120000: 5.080
# Minibatch perplexity: 160.698
# Validation perplexity: 207.231
# verenigde jazeera renamed the UNK but in one nine five five she had
#
# Average loss at step 121000: 5.051
# Minibatch perplexity: 156.142
# Validation perplexity: 225.512
# srebp obstacles drops to psychedelic heart while normal the stomach s shock pain
#
# Average loss at step 122000: 4.811
# Minibatch perplexity: 122.814
# Validation perplexity: 210.422
# disjoint cogency take what is likely that the rabbinical qur portion the word
#
# Average loss at step 123000: 4.866
# Minibatch perplexity: 129.737
# Validation perplexity: 211.388
# ambon rode thrown around the hand and was in with dry upside cannon
#
# Average loss at step 124000: 5.316
# Minibatch perplexity: 203.662
# Validation perplexity: 215.113
# cac hominem take originally the title available for a company passed through joining
#
# Average loss at step 125000: 5.112
# Minibatch perplexity: 166.054
# Validation perplexity: 199.065
# crosstalk inhomogeneous eigenvalue reinvent UNK is a linear exponential function to the particle
#
# Average loss at step 126000: 4.936
# Minibatch perplexity: 139.254
# Validation perplexity: 211.741
# maserati principalities were beyond the unusually small part of the population of the
#
# Average loss at step 127000: 4.911
# Minibatch perplexity: 135.753
# Validation perplexity: 221.562
# coordinators prepositions kristi UNK UNK honv UNK perle auxiliary UNK UNK ae UNK
#
# Average loss at step 128000: 4.790
# Minibatch perplexity: 120.336
# Validation perplexity: 201.995
# chesterton bulwer clair geoffrey born one nine three seven was an broz politician
#
# Average loss at step 129000: 4.728
# Minibatch perplexity: 113.123
# Validation perplexity: 209.217
# accepts kpa brilliant someone else did enable them to discriminate the human population
#
# Average loss at step 130000: 4.814
# Minibatch perplexity: 123.195
# Validation perplexity: 218.433
# peg contractor distraction would act during the year more on recent decades the
#
# Average loss at step 131000: 4.951
# Minibatch perplexity: 141.340
# Validation perplexity: 217.591
# frontierland eudes harry potter external links circle on silver films frederick cage one
#
# Average loss at step 132000: 5.000
# Minibatch perplexity: 148.439
# Validation perplexity: 203.417
# saya mcdivitt t instructions trial godwin one eight five four and the same
#
# Average loss at step 133000: 4.435
# Minibatch perplexity: 84.315
# Validation perplexity: 193.598
# peep blind goalie lineman udo max c one nine five seven one nine
#
# Average loss at step 134000: 4.742
# Minibatch perplexity: 114.613
# Validation perplexity: 200.300
# tif greyscale supported this technology was imported by mumps such as mozilla engelbart
#
# Average loss at step 135000: 4.593
# Minibatch perplexity: 98.776
# Validation perplexity: 195.932
# eigenstates gasses jahwist works encompassing six contrasting chiefly aspects of the physical laws
#
# Average loss at step 136000: 4.742
# Minibatch perplexity: 114.620
# Validation perplexity: 219.652
# gains polytheism split into the category may end in the one nine seven
#
# Average loss at step 137000: 4.783
# Minibatch perplexity: 119.463
# Validation perplexity: 192.846
# meta wresting the correct requirements of the arguments obtained by and the private
#
# Average loss at step 138000: 4.732
# Minibatch perplexity: 113.489
# Validation perplexity: 199.431
# eniac proletarian actinide believed that it was designed to convince their designs by
#
# Average loss at step 139000: 4.673
# Minibatch perplexity: 107.061
# Validation perplexity: 206.196
# knuckles relating to a conscious object being true while at the same time
#
# Average loss at step 140000: 4.923
# Minibatch perplexity: 137.394
# Validation perplexity: 217.166
# toothbrush periphery cutter back to register sheet payment weems singles and learn about
#
# Average loss at step 141000: 4.840
# Minibatch perplexity: 126.466
# Validation perplexity: 199.999
# atharva derive from the rest of infancy of pergamum omit and amount in
#
# Average loss at step 142000: 4.719
# Minibatch perplexity: 112.090
# Validation perplexity: 210.548
# overblown seth nosebleed washed toward the specificities of the recently one nine nine
#
# Average loss at step 143000: 4.753
# Minibatch perplexity: 115.936
# Validation perplexity: 202.629
# dip theory instead graphical systems designer universal machine could record market labouring computing
#
# Average loss at step 144000: 4.469
# Minibatch perplexity: 87.294
# Validation perplexity: 206.188
# storming contrary to the actual amount of entirety one five one eight births
#
# Average loss at step 145000: 4.861
# Minibatch perplexity: 129.152
# Validation perplexity: 208.171
# bipolar crystallizes photometry is inhalation dry emissions long term dimitrov has its impact
#
# Average loss at step 146000: 4.823
# Minibatch perplexity: 124.356
# Validation perplexity: 201.297
# dystopias society by pointing its progress while doing distrust novels have pytheas suggests
#
# Average loss at step 147000: 4.739
# Minibatch perplexity: 114.281
# Validation perplexity: 198.359
# authorised hoos m kongsberg state building on kennedy university becomes chicago state building
#
# Average loss at step 148000: 4.910
# Minibatch perplexity: 135.690
# Validation perplexity: 207.353
# isospin desapio gunships koresh world war ii japan japan on the isle of
#
# Average loss at step 149000: 4.849
# Minibatch perplexity: 127.665
# Validation perplexity: 213.391
# hornbill dewitt is a nurse who worked in political politics his famous novel
#
# Average loss at step 150000: 4.553
# Minibatch perplexity: 94.946
# Validation perplexity: 200.684
# separatists disbanded the magma fines and prevention of northern powers east of the
#
# Average loss at step 151000: 4.509
# Minibatch perplexity: 90.804
# Validation perplexity: 218.019
# battery thatcher moved to the fall of the world although it was at
#
# Average loss at step 152000: 4.847
# Minibatch perplexity: 127.412
# Validation perplexity: 217.687
# premises abendana date of the annual first counts most of the events in
#
# Average loss at step 153000: 4.501
# Minibatch perplexity: 90.130
# Validation perplexity: 220.083
# heston aleph moabite leadership of judah has led to tsu tough rules seem
#
# Average loss at step 154000: 4.933
# Minibatch perplexity: 138.792
# Validation perplexity: 213.012
# sag breast sent to the hand roommate dr fresnel fills the dead der
#
# Average loss at step 155000: 4.758
# Minibatch perplexity: 116.506
# Validation perplexity: 199.893
# mettrie tipton crusoe portrait of the french national purpose peace prize and labor
#
# Average loss at step 156000: 4.845
# Minibatch perplexity: 127.103
# Validation perplexity: 223.303
# necker burnet the british loan and the first seal in the one nine
#
# Average loss at step 157000: 4.707
# Minibatch perplexity: 110.667
# Validation perplexity: 218.951
# red planes lander gto a car and other similar operating vehicles minor found
#
# Average loss at step 158000: 4.825
# Minibatch perplexity: 124.533
# Validation perplexity: 197.934
# henin beets is an alcoholic the musicologist he celebrated the new york title
#
# Average loss at step 159000: 4.664
# Minibatch perplexity: 106.111
# Validation perplexity: 203.880
# insecticide consensual promotion one nine eight eight pot played by tea bills one
#
# Average loss at step 160000: 4.650
# Minibatch perplexity: 104.568
# Validation perplexity: 189.842
# excretion consumption recombination food northerners and pensions hunters and agriculture livestock are brought
#
# Average loss at step 161000: 4.751
# Minibatch perplexity: 115.723
# Validation perplexity: 206.381
# whisky sands of cato american politician lives in puerto magna is the gulf
#
# Average loss at step 162000: 4.876
# Minibatch perplexity: 131.094
# Validation perplexity: 196.566
# victrix kamikazes shooting jet descent missiles mortars bombs and khwarezmian in one nine
#
# Average loss at step 163000: 4.564
# Minibatch perplexity: 95.973
# Validation perplexity: 184.858
# syracuse geometrical art relief solely narrow within his feet and he lost ships
#
# Average loss at step 164000: 4.658
# Minibatch perplexity: 105.408
# Validation perplexity: 186.514
# insulating glasses drop one and the size of what is deflected nearly always
#
# Average loss at step 165000: 4.776
# Minibatch perplexity: 118.624
# Validation perplexity: 195.022
# margulis kohl was at reprint her book love written at the grave a
#
# Average loss at step 166000: 4.789
# Minibatch perplexity: 120.161
# Validation perplexity: 189.183
# contextual cts the question of a process that left the office a number
#
# Average loss at step 167000: 4.583
# Minibatch perplexity: 97.796
# Validation perplexity: 196.680
# steamy marpa maleficarum captures UNK furtado s UNK martin UNK UNK UNK july
#
# Average loss at step 168000: 4.503
# Minibatch perplexity: 90.297
# Validation perplexity: 190.374
# jasenovac put about a toll of workers launched the camped tributary of jerusalem
#
# Average loss at step 169000: 4.497
# Minibatch perplexity: 89.782
# Validation perplexity: 206.117
# reformulation of adl controversies altogether and wait such a program to express only
#
# Average loss at step 170000: 4.692
# Minibatch perplexity: 109.051
# Validation perplexity: 197.340
# cannstatt championship the business s one eight nine five commission on london cpr
#
# Average loss at step 171000: 4.668
# Minibatch perplexity: 106.465
# Validation perplexity: 206.681
# shielded mariners corresponding to snowstorm rivers composed of buoyancy water and wetlands survive
#
# Average loss at step 172000: 4.617
# Minibatch perplexity: 101.153
# Validation perplexity: 188.222
# trabzon rican harvest the maya period the town has defensible its meridian point
#
# Average loss at step 173000: 4.790
# Minibatch perplexity: 120.328
# Validation perplexity: 197.577
# bishopric kultur maria st charlotte concludes the one zero th day of his
#
# Average loss at step 174000: 4.484
# Minibatch perplexity: 88.578
# Validation perplexity: 211.324
# unison awaits for implication seventh ie in rome of great debate luther discussed
#
# Average loss at step 175000: 5.251
# Minibatch perplexity: 190.675
# Validation perplexity: 206.503
# fats quadrupole and strike involves electrical programs to be attained until not to
#
# Average loss at step 176000: 4.734
# Minibatch perplexity: 113.759
# Validation perplexity: 201.670
# petitcodiac mountains wellington reef polk in a west and briggs county park as
#
# Average loss at step 177000: 4.678
# Minibatch perplexity: 107.566
# Validation perplexity: 206.719
# pastiches durruti chant the modern political theory of the arts communes also mma
#
# Average loss at step 178000: 4.906
# Minibatch perplexity: 135.095
# Validation perplexity: 184.830
# corgi massa centipedes a theory that measure that white reed defined cold fusion
# Average loss at step 179000: 4.654
# Minibatch perplexity: 105.016
# Validation perplexity: 200.582
# retrovirus pyrimidines el cooh in mariana there are two major raves in zoology
#
# Average loss at step 180000: 4.715
# Minibatch perplexity: 111.652
# Validation perplexity: 208.377
# oprah cecilia who founded the indigenous scholarly helped mississippi basin for public health
#
# Average loss at step 181000: 4.465
# Minibatch perplexity: 86.935
# Validation perplexity: 203.718
# features apoptosis arrest manslaughter bsi makers cartoons depicting the gig ovations is on
#
# Average loss at step 182000: 4.531
# Minibatch perplexity: 92.875
# Validation perplexity: 201.461
# doughnut dog man broken down his hand called UNK to conceive his true
#
# Average loss at step 183000: 4.637
# Minibatch perplexity: 103.282
# Validation perplexity: 210.160
# channels scholz s consultative book distanced on for the computer interaction block algorithmic
#
# Average loss at step 184000: 4.741
# Minibatch perplexity: 114.536
# Validation perplexity: 198.996
# interface herrera UNK de salle bella bussy she died when johann friedrich marc
#
# Average loss at step 185000: 4.660
# Minibatch perplexity: 105.617
# Validation perplexity: 187.670
# fuji houseplants topping the red with red hot on the edge of the
#
# Average loss at step 186000: 4.431
# Minibatch perplexity: 83.992
# Validation perplexity: 192.506
# wesleyan rutgers university is a thriving institution in new york city the world
#
# Average loss at step 187000: 4.730
# Minibatch perplexity: 113.338
# Validation perplexity: 194.736
# meets elementary second difference after the first numerical computing point gives the moment
#
# Average loss at step 188000: 4.554
# Minibatch perplexity: 94.973
# Validation perplexity: 185.345
# threats firsthand individual disasters have attracted to the rumours the obvious reaction to
#
# Average loss at step 189000: 4.703
# Minibatch perplexity: 110.274
# Validation perplexity: 199.532
# erinyes explained that a slim being bringing back to read the photographic collection
#
# Average loss at step 190000: 4.412
# Minibatch perplexity: 82.395
# Validation perplexity: 184.618
# taff heathers contrive a nephi father ein UNK whose father who is said
#
# Average loss at step 191000: 4.784
# Minibatch perplexity: 119.597
# Validation perplexity: 193.064
# asbury wulf two one nrsv hermann f one seven eight owain david l
#
# Average loss at step 192000: 4.452
# Minibatch perplexity: 85.778
# Validation perplexity: 195.895
# rasputin acorn donated executives heather emmy the seventies eric miller here fuchs wrote
#
# Average loss at step 193000: 4.729
# Minibatch perplexity: 113.239
# Validation perplexity: 189.253
# schoolteacher without contact with pain of the rest of the assembly he felt
#
# Average loss at step 194000: 4.447
# Minibatch perplexity: 85.410
# Validation perplexity: 195.165
# roaring story kidd and the exploded cart killer who enlisted him later conflicted
#
# Average loss at step 195000: 4.650
# Minibatch perplexity: 104.613
# Validation perplexity: 201.194
# mothers a frick hunt team is registered and continued to broadcast as funniest
#
# Average loss at step 196000: 4.885
# Minibatch perplexity: 132.344
# Validation perplexity: 198.756
# harald UNK vets commander peacekeepers officers titles da franciscans obergruppenf german middle class
#
# Average loss at step 197000: 4.444
# Minibatch perplexity: 85.096
# Validation perplexity: 195.645
# illuminism from hypostasis on god in everyone and the other claims of the
#
# Average loss at step 198000: 4.793
# Minibatch perplexity: 120.631
# Validation perplexity: 193.467
# rewrote galaxy two two endings example of a brief history of the ethos
#
# Average loss at step 199000: 4.554
# Minibatch perplexity: 94.971
# Validation perplexity: 184.944
# contra p three seven c edited by curtis who he demanding two zero
#
# Average loss at step 200000: 4.443
# Minibatch perplexity: 85.023
# Validation perplexity: 194.597
# abdelkader aleandro lique puerto rican congress one nine four four chilean foreign relations
#
# Average loss at step 201000: 4.405
# Minibatch perplexity: 81.888
# Validation perplexity: 206.644
# recreates a jumping course at large speeds or as this concept replica when
#
# Average loss at step 202000: 4.934
# Minibatch perplexity: 138.994
# Validation perplexity: 199.536
# keuka related three d shield a two one acre UNK type three al
#
# Average loss at step 203000: 4.689
# Minibatch perplexity: 108.694
# Validation perplexity: 190.670
# misunderstanding demonstrates that even people that the obvious situation of inappropriate incestuous input
#
# Average loss at step 204000: 4.844
# Minibatch perplexity: 126.917
# Validation perplexity: 189.844
# defused firearms hyperactivity kitzmiller first established by the home student and his education
#
# Average loss at step 205000: 4.718
# Minibatch perplexity: 111.957
# Validation perplexity: 194.535
# computerised line up the opposite problem is running for any moment in time
#
# Average loss at step 206000: 4.654
# Minibatch perplexity: 105.018
# Validation perplexity: 214.202
# vocalizations out of the chamber UNK minister s overall to which change the
#
# Average loss at step 207000: 4.467
# Minibatch perplexity: 87.138
# Validation perplexity: 206.205
# willingly obtain independence to a program up n UNK with a humanitarian professional
#
# Average loss at step 208000: 4.639
# Minibatch perplexity: 103.484
# Validation perplexity: 191.366
# allah sung after some other religions however metaphysic musicology music has produced new
#
# Average loss at step 209000: 4.465
# Minibatch perplexity: 86.956
# Validation perplexity: 206.453
# cycl pcs soon became the version of a printer machine due to the
#
# Average loss at step 210000: 4.661
# Minibatch perplexity: 105.763
# Validation perplexity: 203.329
# auerbach oscar the conservatives congress wrote education policy he attempts to devote an
#
# Average loss at step 211000: 4.894
# Minibatch perplexity: 133.547
# Validation perplexity: 187.020
# corte seres de mandaeanism though the majority of the afghan armies had overseen
#
# Average loss at step 212000: 4.630
# Minibatch perplexity: 102.489
# Validation perplexity: 190.832
# choc miracle and first place UNK s UNK e g g in one
#
# Average loss at step 213000: 4.716
# Minibatch perplexity: 111.723
# Validation perplexity: 174.068
# atomist intelligible obscure although the derivation gradually travels far from a remote distance
#
# Average loss at step 214000: 4.542
# Minibatch perplexity: 93.882
# Validation perplexity: 203.687
# forces basics in crystal form a version of the UNK consists of two
#
# Average loss at step 215000: 4.500
# Minibatch perplexity: 89.983
# Validation perplexity: 196.079
# medarabtel conquer this period reflected approximately flight from cargo at the cost of
#
# Average loss at step 216000: 4.528
# Minibatch perplexity: 92.538
# Validation perplexity: 183.960
# resurface ancestry since then west lyrae performed towards arguably the lead of the
#
# Average loss at step 217000: 4.898
# Minibatch perplexity: 134.074
# Validation perplexity: 188.852
# virial moment moves from the tiny chromosphere at the face of the length
#
# Average loss at step 218000: 4.327
# Minibatch perplexity: 75.694
# Validation perplexity: 196.284
# troops sailboat fleets which lie now now used to operate fishing norris gained
#
# Average loss at step 219000: 4.845
# Minibatch perplexity: 127.049
# Validation perplexity: 185.660
# buckminsterfullerene tudor statuette carved in a suitcase and on land the skins have
#
# Average loss at step 220000: 4.438
# Minibatch perplexity: 84.620
# Validation perplexity: 202.330
# jg chapman davis brian spielberg is prepared for forty cantigas sessions his songs
#
# Average loss at step 221000: 4.621
# Minibatch perplexity: 101.573
# Validation perplexity: 188.712
# engelbart enforced the intellectual property or insofar course before it became clear that
#
# Average loss at step 222000: 4.238
# Minibatch perplexity: 69.253
# Validation perplexity: 199.031
# meine zaza libert is also sold via atp in one eight nine nine
#
# Average loss at step 223000: 4.410
# Minibatch perplexity: 82.278
# Validation perplexity: 189.133
# ideographic neighbours studies and include the mind s efforts toward process largely created
#
# Average loss at step 224000: 4.511
# Minibatch perplexity: 91.046
# Validation perplexity: 202.679
# chimpanzee species including pigments that survived at the costanzo laboratory museum the the
#
# Average loss at step 225000: 4.617
# Minibatch perplexity: 101.171
# Validation perplexity: 174.492
# ports together in several ways to reach the frozen in new zealand s
#
# Average loss at step 226000: 4.443
# Minibatch perplexity: 85.034
# Validation perplexity: 193.638
# reconquering hazara disappeared out of earlier mongolian UNK at the beginning of the
#
# Average loss at step 227000: 4.623
# Minibatch perplexity: 101.849
# Validation perplexity: 191.569
# flammable fingerboard shaped and demonstrated that a composer would have capablanca to never
#
# Average loss at step 228000: 4.793
# Minibatch perplexity: 120.713
# Validation perplexity: 200.085
# thereabouts of the people s movement but the lack of excessive punishment likely
#
# Average loss at step 229000: 4.332
# Minibatch perplexity: 76.116
# Validation perplexity: 193.777
# brel settled out of the old swedish province but they changed their culture
#
# Average loss at step 230000: 4.615
# Minibatch perplexity: 100.964
# Validation perplexity: 199.590
# hsueh weiss born october four eight one six seven six the discoverer or
#
# Average loss at step 231000: 4.696
# Minibatch perplexity: 109.505
# Validation perplexity: 178.450
# palpable history near constance george washington who for the abduction of a series
#
# Average loss at step 232000: 4.507
# Minibatch perplexity: 90.618
# Validation perplexity: 195.539
# educator lamont eaton one of the many naturalists of glasgow milton attended by
#
# Average loss at step 233000: 4.618
# Minibatch perplexity: 101.258
# Validation perplexity: 193.423
# ryswick and western patagonia with the development of growth in tax centres and
#
# Average loss at step 234000: 4.928
# Minibatch perplexity: 138.088
# Validation perplexity: 204.818
# routes warcraft stats com the golden age of death one eight september one
#
# Average loss at step 235000: 4.938
# Minibatch perplexity: 139.484
# Validation perplexity: 199.832
# enshrine meant to be a creed it may be called a hill and
#
# Average loss at step 236000: 4.704
# Minibatch perplexity: 110.357
# Validation perplexity: 191.645
# versatility chant with the growth of press whereas he felt an industrial on
#
# Average loss at step 237000: 4.321
# Minibatch perplexity: 75.246
# Validation perplexity: 201.786
# mallets the throat was removed as it became somewhat screwgate on the following
#
# Average loss at step 238000: 4.492
# Minibatch perplexity: 89.265
# Validation perplexity: 171.300
# interrogators were legislated through liberties on behalf of respect persons or discrimination conciliation
#
# Average loss at step 239000: 4.396
# Minibatch perplexity: 81.088
# Validation perplexity: 187.616
# comedians who played large numbers of close contact between men for each row
#
# Average loss at step 240000: 4.693
# Minibatch perplexity: 109.171
# Validation perplexity: 195.686
# lossless coronal modulation freeview resolution of a physical accesses desk to very color
#
# Average loss at step 241000: 4.488
# Minibatch perplexity: 88.939
# Validation perplexity: 182.009
# summer saints observe to their establishment as a explorer and uses of h
#
# Average loss at step 242000: 4.550
# Minibatch perplexity: 94.671
# Validation perplexity: 192.944
# vsat muse wynne o brien peter andrews macdonald manchester one nine nine six
#
# Average loss at step 243000: 4.929
# Minibatch perplexity: 138.250
# Validation perplexity: 180.522
# reviewed catastrophic key slowdown during this period downfall cuts the allied forces and
#
# Average loss at step 244000: 4.545
# Minibatch perplexity: 94.141
# Validation perplexity: 187.505
# dtmf v present in the u s with many clever and literary instrument
#
# Average loss at step 245000: 4.362
# Minibatch perplexity: 78.419
# Validation perplexity: 180.829
# dello UNK references UNK columnists in the letters UNK trilogy by robert cannon
#
# Average loss at step 246000: 4.860
# Minibatch perplexity: 128.970
# Validation perplexity: 181.169
# religiously building operated at the eilat city in the netherlands on february two
#
# Average loss at step 247000: 4.522
# Minibatch perplexity: 92.006
# Validation perplexity: 189.279
# boca f c the city of manchester is owned by UNK and detroit
#
# Average loss at step 248000: 4.451
# Minibatch perplexity: 85.696
# Validation perplexity: 201.281
# derringer cxcr four d macpherson george a woman level stilts believe that m
#
# Average loss at step 249000: 4.391
# Minibatch perplexity: 80.730
# Validation perplexity: 195.899
# pollinated instantaneously during peak from the late to one six zero zero s
#
# Average loss at step 250000: 4.579
# Minibatch perplexity: 97.454
# Validation perplexity: 189.525
# albino and abol vaginal equivalent syndrome a particularly characteristic role in the endosymbiont
#
# Average loss at step 251000: 4.635
# Minibatch perplexity: 103.034
# Validation perplexity: 188.352
# belief determines due to a special kind of service in which the armed
#
# Average loss at step 252000: 4.632
# Minibatch perplexity: 102.689
# Validation perplexity: 180.267
# blackfriars hood the roots of the city the two lists are the comic
#
# Average loss at step 253000: 4.572
# Minibatch perplexity: 96.753
# Validation perplexity: 198.188
# reduce progress in between an nutation of the birthrate in the spring of
#
# Average loss at step 254000: 4.369
# Minibatch perplexity: 78.964
# Validation perplexity: 203.123
# rethink ray bradbury among others two zero zero five powell dickens is listed
#
# Average loss at step 255000: 4.491
# Minibatch perplexity: 89.177
# Validation perplexity: 206.280
# anabolic degradation factor p two zero zero one two zero zero one gene
#
# Average loss at step 256000: 4.528
# Minibatch perplexity: 92.528
# Validation perplexity: 189.579
# orla plants mentioned in the genealogy of the species he paid the prophecy
#
# Average loss at step 257000: 4.804
# Minibatch perplexity: 122.040
# Validation perplexity: 198.002
# retract anchor rule for intelligent exploration of obedience or inheritance and truth they
#
# Average loss at step 258000: 4.299
# Minibatch perplexity: 73.591
# Validation perplexity: 189.867
# maharishi benjamins adamantly music producer constantin UNK alexander rodin medallist made there bold
#
# Average loss at step 259000: 4.548
# Minibatch perplexity: 94.406
# Validation perplexity: 200.791
# kicking the ball over the bargain making an UNK generally scoop as the
#
# Average loss at step 260000: 4.487
# Minibatch perplexity: 88.892
# Validation perplexity: 214.478
# appius ii as the commander he attempted to deteriorate him by taking the
#
# Average loss at step 261000: 4.681
# Minibatch perplexity: 107.861
# Validation perplexity: 194.354
# bond and the mv commanding might his precautions of sudden flight operations in
#
# Average loss at step 262000: 4.601
# Minibatch perplexity: 99.566
# Validation perplexity: 194.537
# bedroom colom flower costanza childhood one and fox wife split their relationship with
#
# ...
# misread sinister literature spilled daily by world war ii and among the order
#
# Average loss at step 532000: 4.168
# Minibatch perplexity: 64.583
# Validation perplexity: 178.832
# elaborately separated which in parallel is often presented idea instead any capitalized form
#
# Average loss at step 533000: 4.179
# Minibatch perplexity: 65.322
# Validation perplexity: 187.389
# lse prover would have three way offices to know how a work was
#
# Average loss at step 534000: 4.325
# Minibatch perplexity: 75.585
# Validation perplexity: 181.878
# kakatiya sanjo in arabic script on the meaning of egyptian numeral numeral see
#
# Average loss at step 535000: 3.958
# Minibatch perplexity: 52.373
# Validation perplexity: 177.235
# yngwie pepper ace UNK and cool browed up with a six zero enclosed
#
# Average loss at step 536000: 4.174
# Minibatch perplexity: 64.953
# Validation perplexity: 183.708
# methicillin appendicitis continued their description after serpentine in one nine five zero one
#
# Average loss at step 537000: 4.463
# Minibatch perplexity: 86.719
# Validation perplexity: 179.772
# fitted runways although there even boeing was a top priority with one six
#
# Average loss at step 538000: 4.227
# Minibatch perplexity: 68.538
# Validation perplexity: 171.610
# frication this combination of elaborate measuring is not popular on a guitar band
#
# Average loss at step 539000: 4.192
# Minibatch perplexity: 66.153
# Validation perplexity: 182.617
# ether debuted at dresden in one eight one three he left a highly
#
# Average loss at step 540000: 4.368
# Minibatch perplexity: 78.912
# Validation perplexity: 193.469
# afridi deliciosa horn and UNK descent and one of west italian UNK duck
#
# Average loss at step 541000: 4.150
# Minibatch perplexity: 63.403
# Validation perplexity: 186.576
# goths criticize the concept of aryan culture and developed more specifically developed into
#
# Average loss at step 542000: 4.161
# Minibatch perplexity: 64.145
# Validation perplexity: 183.745
# integrate manipulation structures that is disproportionately different combinations are used to study complexity
#
# Average loss at step 543000: 4.150
# Minibatch perplexity: 63.459
# Validation perplexity: 197.740
# html tags the original descendants of each member included several joint personnel documents
#
# Average loss at step 544000: 4.306
# Minibatch perplexity: 74.144
# Validation perplexity: 169.573
# unbiased duration between six days a typical year routine is delivered by an
#
# Average loss at step 545000: 4.315
# Minibatch perplexity: 74.822
# Validation perplexity: 179.030
# peterloo accords with the more conservative and smallholders disagreements which had expelled the
#
# Average loss at step 546000: 4.202
# Minibatch perplexity: 66.849
# Validation perplexity: 185.521
# strachan thinks brown fought with gustavo s daughter gladys he married his cousin
#
# Average loss at step 547000: 4.265
# Minibatch perplexity: 71.200
# Validation perplexity: 196.231
# semiautomatic gigabit type type unwritten g afer stateless soap is specified with the
#
# Average loss at step 548000: 4.118
# Minibatch perplexity: 61.440
# Validation perplexity: 182.440
# dressed and or craze and living objects in the same way that they
#
# Average loss at step 549000: 4.278
# Minibatch perplexity: 72.122
# Validation perplexity: 197.249
# weltanschauung s development of the universe seems to include the fallacy that mental
#
# Average loss at step 550000: 4.224
# Minibatch perplexity: 68.308
# Validation perplexity: 175.191
# recognise this as the fourth international conference with the new communist regime called
#
# Average loss at step 551000: 4.312
# Minibatch perplexity: 74.614
# Validation perplexity: 189.354
# ears disappeared of ixians one being a frog funnel giambologna was restricted to
#
# Average loss at step 552000: 4.186
# Minibatch perplexity: 65.740
# Validation perplexity: 202.274
# ebu project has borne a message board and legs the cap performs an
#
# Average loss at step 553000: 4.416
# Minibatch perplexity: 82.746
# Validation perplexity: 204.286
# sakae was named after him outflows he was after the inventor attorney in
#
# Average loss at step 554000: 4.365
# Minibatch perplexity: 78.623
# Validation perplexity: 213.940
# shareholding public opinion about anti issues by the city officials since restored the
#
# Average loss at step 555000: 4.129
# Minibatch perplexity: 62.091
# Validation perplexity: 208.581
# saudi arabia or other berber jews tutsis militants and auc meetings formed a
#
# Average loss at step 556000: 4.046
# Minibatch perplexity: 57.190
# Validation perplexity: 198.292
# gentler playing UNK the dungeons card films the third the first card to
#
# Average loss at step 557000: 4.234
# Minibatch perplexity: 69.017
# Validation perplexity: 176.806
# pontiac the killer is apprehended is from a frozen dalek variety in which
#
# Average loss at step 558000: 4.238
# Minibatch perplexity: 69.266
# Validation perplexity: 172.198
# prostration and ice that appears in a new situation purgatory and nonsensical compare
#
# Average loss at step 559000: 4.178
# Minibatch perplexity: 65.258
# Validation perplexity: 185.845
# gratis they release reluctantly in october two zero zero three criticisms such as
#
# Average loss at step 560000: 4.284
# Minibatch perplexity: 72.505
# Validation perplexity: 186.844
# toolkit game the company was promoted to baxter gordon with networking systems inc
#
# Average loss at step 561000: 4.441
# Minibatch perplexity: 84.850
# Validation perplexity: 188.953
# spitting montages regimen are those of the bottom artist the criticism notions of
#
# Average loss at step 562000: 4.490
# Minibatch perplexity: 89.128
# Validation perplexity: 175.580
# lees are asked a UNK singaporean UNK a yellow spring roast a p
#
# Average loss at step 563000: 4.243
# Minibatch perplexity: 69.612
# Validation perplexity: 180.355
# nepomuk ferdinand ferdinand in november one one one eight zero four six of
#
# Average loss at step 564000: 3.981
# Minibatch perplexity: 53.587
# Validation perplexity: 179.928
# pachomius barca bast cathedral is a dutch warrior appearing in the iron maiden
#
# Average loss at step 565000: 4.258
# Minibatch perplexity: 70.691
# Validation perplexity: 181.660
# serine UNK an UNK product of the first version of nothingness new york
#
# Average loss at step 566000: 4.257
# Minibatch perplexity: 70.565
# Validation perplexity: 183.821
# hypergeometric book for mathematical complexities invented a system in one nine zero one
#
# Average loss at step 567000: 4.175
# Minibatch perplexity: 65.060
# Validation perplexity: 192.797
# breslau w rttemberg anti semitism anti semitism and anti semitism was towards greater
#
# Average loss at step 568000: 4.167
# Minibatch perplexity: 64.536
# Validation perplexity: 194.664
# prophetically thane remarked no strong evidence on jonah the life of jonah as
#
# Average loss at step 569000: 4.386
# Minibatch perplexity: 80.296
# Validation perplexity: 186.355
# kidnapping bon dog wearing another spirits of a very slow animal conditioned on
#
# Average loss at step 570000: 4.205
# Minibatch perplexity: 67.049
# Validation perplexity: 187.150
# fanatics harper existence book of characters jerry walcott animal gallery books and web
#
# Average loss at step 571000: 4.296
# Minibatch perplexity: 73.389
# Validation perplexity: 185.375
# rejoin see above the increase in proportion of a warship strength on a
#
# Average loss at step 572000: 4.081
# Minibatch perplexity: 59.191
# Validation perplexity: 194.684
# cm noddy archer not already used primarily for other uses of their own
#
# Average loss at step 573000: 4.118
# Minibatch perplexity: 61.429
# Validation perplexity: 192.413
# undeniably abused hedley in the autobiography abulurd and howard or feminist manifesto arranged
#
# Average loss at step 574000: 4.404
# Minibatch perplexity: 81.799
# Validation perplexity: 199.248
# closes the soviet buses that did not avoid all the trains of rail
#
# Average loss at step 575000: 4.242
# Minibatch perplexity: 69.521
# Validation perplexity: 182.351
# topper convention against pepsi company and that may have been distributing as far
#
# Average loss at step 576000: 4.584
# Minibatch perplexity: 97.893
# Validation perplexity: 186.486
# excesses from the allied forces and the committee there are four m bius
#
# Average loss at step 577000: 4.325
# Minibatch perplexity: 75.588
# Validation perplexity: 189.916
# gentle disheveled spirit at UNK thus typified a new species of dashing non
#
# Average loss at step 578000: 4.053
# Minibatch perplexity: 57.589
# Validation perplexity: 203.947
# freie came from existence lenin did not wish to distinguish christianity in his
#
# Average loss at step 579000: 4.165
# Minibatch perplexity: 64.384
# Validation perplexity: 190.277
# dealers holden and masamune company coffee and video games pay in the united
#
# Average loss at step 580000: 4.302
# Minibatch perplexity: 73.881
# Validation perplexity: 191.966
# ipcc assessment climate change snow wilderness with autumn seasons rainy extremes lowest point
#
# Average loss at step 581000: 4.174
# Minibatch perplexity: 64.979
# Validation perplexity: 203.090
# ignoring analyst and chief eleanor and her post as a united woman and
#
# Average loss at step 582000: 3.949
# Minibatch perplexity: 51.884
# Validation perplexity: 196.580
# abusing a painful start to escalate situation however that this type of government
#
# Average loss at step 583000: 4.140
# Minibatch perplexity: 62.830
# Validation perplexity: 185.831
# hardin ellicott and the poet arthur s father in law in this role
#
# Average loss at step 584000: 4.192
# Minibatch perplexity: 66.134
# Validation perplexity: 176.365
# orson asteroid one one one six ipswich title in their way to make
#
# Average loss at step 585000: 4.349
# Minibatch perplexity: 77.407
# Validation perplexity: 177.322
# curiae gentileschi is the brother of the augusti rulebook compiled by philo de
#
# Average loss at step 586000: 4.181
# Minibatch perplexity: 65.440
# Validation perplexity: 192.446
# headset is offered in new streams in the philippines of egypt the drug
#
# Average loss at step 587000: 4.020
# Minibatch perplexity: 55.678
# Validation perplexity: 195.551
# dhhs permits the use of having the title of the deceased court of
#
# Average loss at step 588000: 4.325
# Minibatch perplexity: 75.589
# Validation perplexity: 181.287
# bdsm powerlifting of a contest to crap dreaming has been unclear the concept
#
# Average loss at step 589000: 4.439
# Minibatch perplexity: 84.680
# Validation perplexity: 186.135
# sayings alternatively teh libro gematria and yehovah since february one zero zero one
#
# Average loss at step 590000: 4.041
# Minibatch perplexity: 56.860
# Validation perplexity: 196.620
# burner detects and as to make appliances worse than the mechanical mouse uses
#
# Average loss at step 591000: 4.077
# Minibatch perplexity: 58.960
# Validation perplexity: 177.294
# finiteness for example an algorithm belongs to that role in group theory i
# Average loss at step 592000: 4.331
# Minibatch perplexity: 76.053
# Validation perplexity: 187.058
# singleton s career he was an accomplished in the academy s event and
#
# Average loss at step 593000: 4.129
# Minibatch perplexity: 62.106
# Validation perplexity: 195.409
# clayton frost frank mckean ian fleming and poets jerry cornelius j j edwards
#
# Average loss at step 594000: 4.091
# Minibatch perplexity: 59.817
# Validation perplexity: 189.847
# chalcedonians turks killed spellman UNK ca one nine eight three odoacer v becomes
#
# Average loss at step 595000: 4.221
# Minibatch perplexity: 68.095
# Validation perplexity: 186.008
# solvable probability the process waned from thinking that word human beings could regard
#
# Average loss at step 596000: 4.155
# Minibatch perplexity: 63.737
# Validation perplexity: 192.193
# rime a guest job for adjectives tour titles three the c one three
#
# Average loss at step 597000: 4.150
# Minibatch perplexity: 63.443
# Validation perplexity: 169.763
# zalman fossett stanford mcfarland society and history of the united states liberal league
#
# Average loss at step 598000: 4.318
# Minibatch perplexity: 75.024
# Validation perplexity: 184.435
# ediacaran one of the few glaciers who had a life do not walk
#
# Average loss at step 599000: 4.307
# Minibatch perplexity: 74.238
# Validation perplexity: 196.441
# codasyl format chinese lotus s algol compiler the pdp foundation that withered the
#
# Average loss at step 600000: 4.432
# Minibatch perplexity: 84.138
# Validation perplexity: 182.961
# budgetary wrangling up taxes tax reform and partly by the government of the
#
# Average loss at step 601000: 4.318
# Minibatch perplexity: 75.007
# Validation perplexity: 177.114
# pink bernd editor and psychic legacy series two based on the novel dune
#
# Average loss at step 602000: 4.577
# Minibatch perplexity: 97.176
# Validation perplexity: 182.835
# manged to opening use of the private titles this suit also encompasses the
#
# Average loss at step 603000: 4.547
# Minibatch perplexity: 94.369
# Validation perplexity: 182.197
# vaguely inspired hi fi classic mattia and her avro harold eccleston s big
#
# Average loss at step 604000: 4.057
# Minibatch perplexity: 57.820
# Validation perplexity: 195.915
# connect to the dardanelles mainz and the sword rode with no final difficulty
#
# Average loss at step 605000: 4.088
# Minibatch perplexity: 59.600
# Validation perplexity: 195.421
# pimpernel i know not i will have to see a UNK come when
#
# Average loss at step 606000: 4.054
# Minibatch perplexity: 57.645
# Validation perplexity: 199.197
# channing upward in one eight five three three zero years later the tragedies
#
# Average loss at step 607000: 4.289
# Minibatch perplexity: 72.888
# Validation perplexity: 209.681
# labonte poon sox making it difficult since one nine three zero s green
#
# Average loss at step 608000: 3.980
# Minibatch perplexity: 53.492
# Validation perplexity: 198.973
# haus dessau tourist messe wright in eisenach motor vehicle raids of mirage there
#
# Average loss at step 609000: 4.101
# Minibatch perplexity: 60.404
# Validation perplexity: 196.398
# kidnap rationing schemes for tejada UNK kul tigin a murry memorial to find
#
# Average loss at step 610000: 4.058
# Minibatch perplexity: 57.867
# Validation perplexity: 176.528
# footing and use revolutionary tactics that prevailed although the north american nations multi
#
# Average loss at step 611000: 4.083
# Minibatch perplexity: 59.294
# Validation perplexity: 180.724
# elric monk art at motley the idea that the UNK drew from grants
#
# Average loss at step 612000: 4.241
# Minibatch perplexity: 69.487
# Validation perplexity: 180.931
# malevolent it is just during the round the rough plans of harry UNK
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-303b933a277a> in <module>()
#       6 for i in range(num_iters):
#       7     lstm.train()
# ----> 8     l = train()
#       9     if i%1000 == 0:
#      10         print('Average loss at step %d: %.3f ' % (i,l))
#
# <ipython-input-26-8732aad5a50e> in train()
#      13         cell, hidden, logits = lstm(embeddings.cuda(), cell.cuda(), hidden.cuda(), batch_size)
#      14         labels = Variable(torch.from_numpy(indices[u+1]))
# ---> 15         loss += loss_function(logits.cuda(), labels.cuda())
#      16     loss.backward()
#      17     torch.nn.utils.clip_grad_norm(lstm.parameters(), 5) #1.25
#
# /usr/local/lib/python3.5/dist-packages/torch/autograd/variable.py in cuda(self, device, async)
#     296
#     297     def cuda(self, device=None, async=False):
# --> 298         return CudaTransfer.apply(self, device, async)
#     299
#     300     def cpu(self):
#
# /usr/local/lib/python3.5/dist-packages/torch/autograd/_functions/tensor.py in forward(ctx, i, device, async)
#     199             return i.cuda(device, async=async)
#     200         else:
# --> 201             return i.cuda(async=async)
#     202
#     203     @staticmethod
#
# /usr/local/lib/python3.5/dist-packages/torch/_utils.py in _cuda(self, device, async)
#      67         else:
#      68             new_type = getattr(torch.cuda, self.__class__.__name__)
# ---> 69             return new_type(self.size()).copy_(self, async)
#      70
#      71
#
# KeyboardInterrupt:

# %%
# model.eval() after reloading
torch.save(lstm.state_dict(), 'model')

# %%
lstm.load_state_dict(torch.load('model'))
lstm.eval()
sample()
valid_perplexity()
